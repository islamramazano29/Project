# %% [markdown]
# <a href="https://colab.research.google.com/github/islamramazano29/Project/blob/master/spiral.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Генерация случайного списка и его сортировка**

# %%
from random import randint
def gen_seq():
  seq = []
  for i in range(10):
    a = randint(0, 101)
    seq.append(a)
  return seq

def sort_seq(list_1):
  for i in range(len(list_1)):
    for j in range(len(list_1) - 1):
      if list_1[j] > list_1[j+1]:
                   list_1[j], list_1[j+1] = list_1[j+1], list_1[j]
  return list_1

print(gen_seq())
print(sort_seq(gen_seq()))
# Out:
# [15, 39, 6, 5, 91, 52, 72, 4, 47, 5]
# [11, 13, 14, 18, 25, 37, 40, 45, 64, 71]

# %% [markdown]
# **Заполнение квадратной матрицы "спиралью"**

# %%
def spiral(n):
    matrix = []
    for i in range(n):
        row = [0] * n
        matrix.append(row)

    left, right, top, bottom = 0, n-1, 0, n-1
    num = 1
    while top < bottom and left < right:
        for i in range(left, right+1):
            matrix[top][i] = num
            num += 1
        top += 1

        for i in range(top, bottom+1):
            matrix[i][right] = num
            num += 1
        right -= 1

        for i in range(right, left-1, -1):
            matrix[bottom][i] = num
            num += 1
        bottom -= 1

        for i in range(bottom, top-1, -1):
            matrix[i][left] = num
            num += 1
        left += 1

    return matrix

mat = spiral(5)
print(mat)
# Out:
# [[1, 2, 3, 4, 5], [16, 17, 18, 19, 6], [15, 24, 0, 20, 7], [14, 23, 22, 21, 8], [13, 12, 11, 10, 9]]
