# %% [markdown]
# <a href="https://colab.research.google.com/github/islamramazano29/Project/blob/master/monte_karlo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Монте Карло**

# %%
import random
import math

R = 1
N_total = 1000000
points_in_target = 0

for i in range(N_total):
    circle_idx = random.randint(0, 2)
    if circle_idx == 0:
        cx, cy = -1, 0
    elif circle_idx == 1:
        cx, cy = 0, 0
    else:
        cx, cy = 1, 0
